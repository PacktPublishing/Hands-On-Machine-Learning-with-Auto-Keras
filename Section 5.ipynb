# %% [markdown]
# # 5. Sentiment analysis

# %% [markdown]
# ### 5.2. Auto-Keras’ pre-trained models for sentiment analysis on a real-world data set

# %%
# pip install autokeras-pretrained
from autokeras_pretrained.text_classifier import SentimentAnalysis
sentiment_analyser = SentimentAnalysis()

polarity = sentiment_analyser.predict("The model is working well.")
print(polarity)

# %%
from keras.datasets import imdb

(x_train, y_train), (x_test, y_test) = imdb.load_data()
print(x_train[2])
word_indexes = imdb.get_word_index(path="imdb_word_index.json")
indexes_to_word = {}
for key, value in word_indexes.items():
    indexes_to_word[value] = key
x_test_str = []
for i in range(x_test.shape[0]):
    x_test_str.append(' '.join([indexes_to_word.get(x - 3, '?') for x in x_test[i]]))
print(x_test_str[0], sentiment_analyser.predict(x_test_str[0]))

# %%
y_pred = [round(sentiment_analyser.predict(test)) for test in x_test_str]

# %%
import numpy as np
sum(np.array(y_pred) == y_test) / len(y_test)

# %% [markdown]
# ### 5.3. The pre-trained models on some of our own data

# %%
# inspired by: https://towardsdatascience.com/customer-reviews-identify-your-strengths-and-weaknesses-with-the-help-of-web-scraping-data-b87a3636ef55

from bs4 import BeautifulSoup # pip install beautifulsoup4
from time import sleep
import requests # pip install requests

def scrape_reviews(PATH, n_pages, sleep_time = 0.3):
    reviews = []

    for p in range(n_pages):

        sleep(sleep_time)

        http = requests.get(f'{PATH}?page={p+1}')
        bsoup = BeautifulSoup(http.text, 'html.parser')
        
        review_containers = bsoup.find_all('div', class_ = 'review-content__body')

        for x in range(len(review_containers)):

            review_c = review_containers[x]
            reviews.append(review_c.p.text)
    
    return reviews

# %%
from autokeras_pretrained.text_classifier import SentimentAnalysis
sentiment_analyser = SentimentAnalysis()

reviews = scrape_reviews(
    PATH = 'https://www.trustpilot.com/review/www.amazon.com',
    n_pages = 2)
for i, review in enumerate(reviews):
    print('Polarity of review #{} is {}'.format(
        i+1, 
        sentiment_analyser.predict(review)))

# %% [markdown]
# ### 5.4 Auto-Keras classifier for sentiment analysis

# %%
from autokeras import TextClassifier
from keras.datasets import imdb
from sklearn.utils import shuffle

def convert_labels_to_one_hot(labels, num_classes):
    one_hot = np.zeros((len(labels), num_classes))
    one_hot[np.arange(len(labels)), labels] = 1
    return one_hot

(x_train, y_train), (x_test, y_test) = imdb.load_data()
x_train, y_train, x_test, y_test = shuffle(x_train, y_train, x_test, y_test)

word_indexes = imdb.get_word_index(path="imdb_word_index.json")
indexes_to_word = {}
for key, value in word_indexes.items():
    indexes_to_word[value] = key
x_train_str = []
x_test_str = []
for i in range(x_train.shape[0]):
    x_train_str.append(' '.join([indexes_to_word.get(x - 3, '?') for x in x_train[i]]))
for i in range(x_test.shape[0]):
    x_test_str.append(' '.join([indexes_to_word.get(x - 3, '?') for x in x_test[i]]))

y_train = convert_labels_to_one_hot(y_train, 2)
y_test = convert_labels_to_one_hot(y_test, 2)
clf = TextClassifier(verbose=True)
clf.fit(x=x_train_str[:1000], y=y_train[:1000], time_limit=20 * 60)
print(clf.evaluate(x_test_str, y_test))

# %% [markdown]
# ### 5.5 Auto-Keras regressor for sentiment analysis

# %%
from keras.datasets import imdb
from sklearn.utils import shuffle

(x_train, y_train), (x_test, y_test) = imdb.load_data()
x_train, y_train, x_test, y_test = shuffle(x_train, y_train, x_test, y_test)

word_indexes = imdb.get_word_index(path="imdb_word_index.json")
indexes_to_word = {}
for key, value in word_indexes.items():
    indexes_to_word[value] = key
x_train_str = []
for i in range(x_train.shape[0]):
    x_train_str.append(' '.join([indexes_to_word.get(x - 3, '?') for x in x_train[i]]))

# %%
from autokeras.text.text_supervised import TextRegressor
reg = TextRegressor(verbose=True)
reg.fit(x=x_train_str[:1000], y=y_train[:1000], time_limit=20 * 60)
# Out:
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/32 [00:00<?, ?it/s]
# ***** Running training *****
# Num examples = %d 1000
# Batch size = %d 32
# Num steps = %d 125
# Iteration:   3%|▎         | 1/32 [00:06<03:23,  6.57s/it]
# Iteration:   6%|▋         | 2/32 [00:15<03:37,  7.26s/it]
# Iteration:   9%|▉         | 3/32 [00:22<03:25,  7.10s/it]
# Iteration:  12%|█▎        | 4/32 [00:29<03:18,  7.09s/it]
# Iteration:  16%|█▌        | 5/32 [00:35<03:05,  6.87s/it]
# Iteration:  19%|█▉        | 6/32 [00:42<02:56,  6.80s/it]
# Iteration:  22%|██▏       | 7/32 [00:48<02:46,  6.66s/it]
# Iteration:  25%|██▌       | 8/32 [00:54<02:34,  6.44s/it]
# Iteration:  28%|██▊       | 9/32 [01:00<02:26,  6.38s/it]
# Iteration:  31%|███▏      | 10/32 [01:07<02:22,  6.45s/it]
# Iteration:  34%|███▍      | 11/32 [01:13<02:13,  6.33s/it]
# Iteration:  38%|███▊      | 12/32 [01:19<02:07,  6.35s/it]
# Iteration:  41%|████      | 13/32 [01:26<02:02,  6.44s/it]
# Iteration:  44%|████▍     | 14/32 [01:32<01:54,  6.35s/it]
# Iteration:  47%|████▋     | 15/32 [01:38<01:44,  6.18s/it]
# Iteration:  50%|█████     | 16/32 [01:44<01:38,  6.15s/it]
# Iteration:  53%|█████▎    | 17/32 [01:50<01:34,  6.27s/it]
# Iteration:  56%|█████▋    | 18/32 [01:57<01:28,  6.29s/it]
# Iteration:  59%|█████▉    | 19/32 [02:03<01:21,  6.27s/it]
# Iteration:  62%|██████▎   | 20/32 [02:09<01:14,  6.22s/it]
# Iteration:  66%|██████▌   | 21/32 [02:15<01:08,  6.22s/it]
# Iteration:  69%|██████▉   | 22/32 [02:22<01:02,  6.22s/it]
# Iteration:  72%|███████▏  | 23/32 [02:28<00:55,  6.15s/it]
# Iteration:  75%|███████▌  | 24/32 [02:35<00:51,  6.47s/it]
# Iteration:  78%|███████▊  | 25/32 [02:41<00:44,  6.38s/it]
# Iteration:  81%|████████▏ | 26/32 [02:47<00:37,  6.27s/it]
# Iteration:  84%|████████▍ | 27/32 [02:54<00:31,  6.35s/it]
# Iteration:  88%|████████▊ | 28/32 [03:00<00:25,  6.47s/it]
# Iteration:  91%|█████████ | 29/32 [03:07<00:19,  6.63s/it]
# Iteration:  94%|█████████▍| 30/32 [03:13<00:12,  6.46s/it]
# Iteration:  97%|█████████▋| 31/32 [03:20<00:06,  6.54s/it]
# Epoch:  25%|██▌       | 1/4 [03:22<10:08, 202.76s/it]s/it]
# Iteration:   0%|          | 0/32 [00:00<?, ?it/s]
# Iteration:   3%|▎         | 1/32 [00:07<03:37,  7.00s/it]
# Iteration:   6%|▋         | 2/32 [00:13<03:24,  6.82s/it]
# Iteration:   9%|▉         | 3/32 [00:20<03:16,  6.78s/it]
# Iteration:  12%|█▎        | 4/32 [00:26<03:06,  6.65s/it]
# Iteration:  16%|█▌        | 5/32 [00:33<03:02,  6.75s/it]
# Iteration:  19%|█▉        | 6/32 [00:39<02:51,  6.60s/it]
# Iteration:  22%|██▏       | 7/32 [00:46<02:49,  6.78s/it]
# Iteration:  25%|██▌       | 8/32 [00:53<02:38,  6.61s/it]
# Iteration:  28%|██▊       | 9/32 [00:59<02:30,  6.55s/it]
# Iteration:  31%|███▏      | 10/32 [01:06<02:24,  6.57s/it]
# Iteration:  34%|███▍      | 11/32 [01:12<02:19,  6.63s/it]
# Iteration:  38%|███▊      | 12/32 [01:19<02:11,  6.59s/it]
# Iteration:  41%|████      | 13/32 [01:26<02:06,  6.65s/it]
# Iteration:  44%|████▍     | 14/32 [01:32<01:57,  6.56s/it]
# Iteration:  47%|████▋     | 15/32 [01:39<01:51,  6.58s/it]
# Iteration:  50%|█████     | 16/32 [01:45<01:44,  6.52s/it]
# Iteration:  53%|█████▎    | 17/32 [01:52<01:39,  6.64s/it]
# Iteration:  56%|█████▋    | 18/32 [01:58<01:30,  6.50s/it]
# Iteration:  59%|█████▉    | 19/32 [02:06<01:28,  6.77s/it]
# Iteration:  62%|██████▎   | 20/32 [02:12<01:20,  6.71s/it]
# Iteration:  66%|██████▌   | 21/32 [02:19<01:13,  6.64s/it]
# Iteration:  69%|██████▉   | 22/32 [02:25<01:05,  6.52s/it]
# Iteration:  72%|███████▏  | 23/32 [02:31<00:58,  6.51s/it]
# Iteration:  75%|███████▌  | 24/32 [02:37<00:50,  6.35s/it]
# Iteration:  78%|███████▊  | 25/32 [02:44<00:45,  6.43s/it]
# Iteration:  81%|████████▏ | 26/32 [02:50<00:38,  6.36s/it]
# Iteration:  84%|████████▍ | 27/32 [02:57<00:32,  6.49s/it]
# Iteration:  88%|████████▊ | 28/32 [03:03<00:25,  6.47s/it]
# Iteration:  91%|█████████ | 29/32 [03:10<00:19,  6.51s/it]
# Iteration:  94%|█████████▍| 30/32 [03:18<00:13,  6.94s/it]
# Iteration:  97%|█████████▋| 31/32 [03:25<00:06,  6.92s/it]
# Epoch:  50%|█████     | 2/4 [06:49<06:48, 204.09s/it]s/it]
# Iteration:   0%|          | 0/32 [00:00<?, ?it/s]
# Iteration:   3%|▎         | 1/32 [00:06<03:22,  6.53s/it]
# Iteration:   6%|▋         | 2/32 [00:13<03:17,  6.60s/it]
# Iteration:   9%|▉         | 3/32 [00:19<03:05,  6.39s/it]
# Iteration:  12%|█▎        | 4/32 [00:26<03:03,  6.55s/it]
# Iteration:  16%|█▌        | 5/32 [00:32<02:57,  6.57s/it]
# Iteration:  19%|█▉        | 6/32 [00:39<02:53,  6.69s/it]
# Iteration:  22%|██▏       | 7/32 [00:46<02:45,  6.64s/it]
# Iteration:  25%|██▌       | 8/32 [00:52<02:38,  6.61s/it]
# Iteration:  28%|██▊       | 9/32 [00:59<02:33,  6.66s/it]
# Iteration:  31%|███▏      | 10/32 [01:06<02:25,  6.63s/it]
# Iteration:  34%|███▍      | 11/32 [01:12<02:15,  6.47s/it]
# Iteration:  38%|███▊      | 12/32 [01:18<02:08,  6.41s/it]
# Iteration:  41%|████      | 13/32 [01:25<02:05,  6.58s/it]
# Iteration:  44%|████▍     | 14/32 [01:32<01:58,  6.59s/it]
# Iteration:  47%|████▋     | 15/32 [01:37<01:48,  6.37s/it]
# Iteration:  50%|█████     | 16/32 [01:44<01:41,  6.37s/it]
# Iteration:  53%|█████▎    | 17/32 [01:50<01:34,  6.33s/it]
# Iteration:  56%|█████▋    | 18/32 [01:56<01:27,  6.26s/it]
# Iteration:  59%|█████▉    | 19/32 [02:03<01:23,  6.43s/it]
# Iteration:  62%|██████▎   | 20/32 [02:10<01:17,  6.49s/it]
# Iteration:  66%|██████▌   | 21/32 [02:16<01:10,  6.42s/it]
# Iteration:  69%|██████▉   | 22/32 [02:23<01:07,  6.74s/it]
# Iteration:  72%|███████▏  | 23/32 [02:30<01:00,  6.76s/it]
# Iteration:  75%|███████▌  | 24/32 [02:36<00:52,  6.55s/it]
# Iteration:  78%|███████▊  | 25/32 [02:43<00:45,  6.55s/it]
# Iteration:  81%|████████▏ | 26/32 [02:49<00:39,  6.54s/it]
# Iteration:  84%|████████▍ | 27/32 [02:55<00:32,  6.42s/it]
# Iteration:  88%|████████▊ | 28/32 [03:01<00:25,  6.33s/it]
# Iteration:  91%|█████████ | 29/32 [03:08<00:19,  6.36s/it]
# Iteration:  94%|█████████▍| 30/32 [03:14<00:12,  6.29s/it]
# Iteration:  97%|█████████▋| 31/32 [03:20<00:06,  6.15s/it]
# Epoch:  75%|███████▌  | 3/4 [10:12<03:23, 203.58s/it]s/it]
# Iteration:   0%|          | 0/32 [00:00<?, ?it/s]
# Iteration:   3%|▎         | 1/32 [00:06<03:20,  6.48s/it]
# Iteration:   6%|▋         | 2/32 [00:12<03:13,  6.45s/it]
# Iteration:   9%|▉         | 3/32 [00:19<03:05,  6.40s/it]
# Iteration:  12%|█▎        | 4/32 [00:25<02:59,  6.41s/it]
# Iteration:  16%|█▌        | 5/32 [00:31<02:51,  6.37s/it]
# Iteration:  19%|█▉        | 6/32 [00:37<02:43,  6.29s/it]
# Iteration:  22%|██▏       | 7/32 [00:44<02:41,  6.47s/it]
# Iteration:  25%|██▌       | 8/32 [00:51<02:35,  6.49s/it]
# Iteration:  28%|██▊       | 9/32 [00:57<02:28,  6.47s/it]
# Iteration:  31%|███▏      | 10/32 [01:04<02:23,  6.53s/it]
# Iteration:  34%|███▍      | 11/32 [01:11<02:18,  6.61s/it]
# Iteration:  38%|███▊      | 12/32 [01:17<02:08,  6.42s/it]
# Iteration:  41%|████      | 13/32 [01:24<02:06,  6.68s/it]
# Iteration:  44%|████▍     | 14/32 [01:30<01:56,  6.46s/it]
# Iteration:  47%|████▋     | 15/32 [01:36<01:48,  6.41s/it]
# Iteration:  50%|█████     | 16/32 [01:42<01:40,  6.29s/it]
# Iteration:  53%|█████▎    | 17/32 [01:50<01:38,  6.58s/it]
# Iteration:  56%|█████▋    | 18/32 [01:56<01:31,  6.57s/it]
# Iteration:  59%|█████▉    | 19/32 [02:03<01:25,  6.56s/it]
# Iteration:  62%|██████▎   | 20/32 [02:09<01:18,  6.50s/it]
# Iteration:  66%|██████▌   | 21/32 [02:16<01:11,  6.52s/it]
# Iteration:  69%|██████▉   | 22/32 [02:22<01:05,  6.50s/it]
# Iteration:  72%|███████▏  | 23/32 [02:29<00:58,  6.52s/it]
# Iteration:  75%|███████▌  | 24/32 [02:35<00:50,  6.34s/it]
# Iteration:  78%|███████▊  | 25/32 [02:41<00:44,  6.33s/it]
# Iteration:  81%|████████▏ | 26/32 [02:47<00:37,  6.23s/it]
# Iteration:  84%|████████▍ | 27/32 [02:53<00:31,  6.25s/it]
# Iteration:  88%|████████▊ | 28/32 [02:59<00:24,  6.24s/it]
# Iteration:  91%|█████████ | 29/32 [03:05<00:18,  6.19s/it]
# Iteration:  94%|█████████▍| 30/32 [03:11<00:12,  6.12s/it]
# Iteration:  97%|█████████▋| 31/32 [03:17<00:06,  6.13s/it]
# Epoch: 100%|██████████| 4/4 [13:32<00:00, 202.43s/it]s/it]
# Training loss = %d 8.120004683732986

# %%
from autokeras_pretrained.text_classifier import SentimentAnalysis

sentiment_analyser = SentimentAnalysis()

reviews = scrape_reviews(
    PATH = 'https://www.trustpilot.com/review/www.amazon.com',
    n_pages = 1)
for i, review in enumerate(reviews):
    print('Polarity of review #{} is: pretrained={}, trained={}'.format(
        i+1, 
        sentiment_analyser.predict(review),
        reg.predict([review])))
# Out:
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #1 is: pretrained=0.009999999776482582, trained=[array([0.5133126], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #2 is: pretrained=0.03999999910593033, trained=[array([0.5153506], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #3 is: pretrained=0.8899999856948853, trained=[array([0.51737946], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #4 is: pretrained=0.25, trained=[array([0.51483184], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #5 is: pretrained=0.0, trained=[array([0.51553065], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #6 is: pretrained=0.05000000074505806, trained=[array([0.5125192], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #7 is: pretrained=0.20999999344348907, trained=[array([0.51678777], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #8 is: pretrained=0.949999988079071, trained=[array([0.51726747], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #9 is: pretrained=0.029999999329447746, trained=[array([0.51657736], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #10 is: pretrained=0.7099999785423279, trained=[array([0.5161373], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #11 is: pretrained=0.0, trained=[array([0.51441973], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #12 is: pretrained=0.019999999552965164, trained=[array([0.513646], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #13 is: pretrained=0.9200000166893005, trained=[array([0.5122231], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #14 is: pretrained=0.03999999910593033, trained=[array([0.51445097], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #15 is: pretrained=0.5, trained=[array([0.515547], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #16 is: pretrained=0.019999999552965164, trained=[array([0.5140622], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #17 is: pretrained=0.7799999713897705, trained=[array([0.5179564], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #18 is: pretrained=0.009999999776482582, trained=[array([0.5100842], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #19 is: pretrained=0.0, trained=[array([0.51554674], dtype=float32)]
# ***** Running evaluation *****
#   Num examples = %d 1
#   Batch size = %d 32
# Polarity of review #20 is: pretrained=0.8999999761581421, trained=[array([0.51713395], dtype=float32)]
